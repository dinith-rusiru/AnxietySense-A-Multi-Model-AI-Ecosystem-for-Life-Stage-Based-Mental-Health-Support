# %%
pip install tensorflow keras opencv-python numpy matplotlib scikit-learn
# Out:
# Requirement already satisfied: tensorflow in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (2.20.0)
# Requirement already satisfied: keras in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (3.13.0)
# Requirement already satisfied: opencv-python in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (3.10.8)
# Requirement already satisfied: scikit-learn in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (1.8.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (6.33.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.4)
# Requirement already satisfied: rich in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from keras) (0.18.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\LENOVO LOQ\Desktop\RN- 2\train model\venv\Scripts\python.exe -m pip install --upgrade pip

# %%
pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (7.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipykernel) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipykernel) (9.8.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipykernel) (8.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipykernel) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipykernel) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\lenovo loq\desktop\rn- 2\train model\venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\LENOVO LOQ\Desktop\RN- 2\train model\venv\Scripts\python.exe -m pip install --upgrade pip

# %%
# !python -m ipykernel install --user --name cnn_env
# Out:
# Installed kernelspec cnn_env in C:\Users\LENOVO LOQ\AppData\Roaming\jupyter\kernels\cnn_env

# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# C:\Users\LENOVO LOQ\Desktop\RN- 2\train model\venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
DATASET_PATH = r"C:\Users\LENOVO LOQ\Desktop\AnxietySense-A-Multi-Model-AI-Ecosystem-for-Life-Stage-Based-Mental-Health-Support\train model\data new\face data"

IMG_SIZE = 48
BATCH_SIZE = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="training"
)

val_data = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="validation"
)

emotion_labels = train_data.class_indices
print("Emotion labels:", emotion_labels)
# Out:
# Found 28711 images belonging to 2 classes.
# Found 7176 images belonging to 2 classes.
# Emotion labels: {'test': 0, 'train': 1}

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(48,48,1)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(emotion_labels), activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# C:\Users\LENOVO LOQ\Desktop\RN- 2\train model\venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 46, 46, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 23, 23, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 21, 21, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 355,202 (1.35 MB)
#  Trainable params: 355,202 (1.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=15
)
# Out:
# Epoch 1/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 827s 918ms/step - accuracy: 0.7994 - loss: 0.5085 - val_accuracy: 0.8000 - val_loss: 0.5100
# Epoch 2/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 445s 495ms/step - accuracy: 0.8000 - loss: 0.5049 - val_accuracy: 0.8000 - val_loss: 0.5006
# Epoch 3/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 121s 71ms/step - accuracy: 0.8000 - loss: 0.5040 - val_accuracy: 0.8000 - val_loss: 0.5010
# Epoch 4/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 68s 75ms/step - accuracy: 0.8000 - loss: 0.5027 - val_accuracy: 0.8000 - val_loss: 0.5004
# Epoch 5/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 77s 69ms/step - accuracy: 0.8000 - loss: 0.5020 - val_accuracy: 0.8000 - val_loss: 0.5004
# Epoch 6/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 85s 72ms/step - accuracy: 0.8000 - loss: 0.5015 - val_accuracy: 0.8000 - val_loss: 0.5004
# Epoch 7/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 62s 69ms/step - accuracy: 0.8000 - loss: 0.5013 - val_accuracy: 0.8000 - val_loss: 0.5004
# Epoch 8/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 64s 71ms/step - accuracy: 0.8000 - loss: 0.5013 - val_accuracy: 0.8000 - val_loss: 0.5040
# Epoch 9/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 61s 68ms/step - accuracy: 0.8000 - loss: 0.5013 - val_accuracy: 0.8000 - val_loss: 0.5005
# Epoch 10/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 69s 76ms/step - accuracy: 0.8000 - loss: 0.5010 - val_accuracy: 0.8000 - val_loss: 0.5012
# Epoch 11/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 65s 73ms/step - accuracy: 0.8000 - loss: 0.5008 - val_accuracy: 0.8000 - val_loss: 0.5013
# Epoch 12/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 64s 71ms/step - accuracy: 0.8000 - loss: 0.5008 - val_accuracy: 0.8000 - val_loss: 0.5015
# Epoch 13/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 43s 48ms/step - accuracy: 0.8000 - loss: 0.5008 - val_accuracy: 0.8000 - val_loss: 0.5006
# Epoch 14/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 67s 75ms/step - accuracy: 0.8000 - loss: 0.5003 - val_accuracy: 0.8000 - val_loss: 0.5014
# Epoch 15/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 82s 75ms/step - accuracy: 0.8000 - loss: 0.5002 - val_accuracy: 0.8000 - val_loss: 0.5011

# %%
loss, accuracy = model.evaluate(val_data)
print(f"Validation Accuracy: {accuracy*100:.2f}%")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.8000 - loss: 0.5011
# Validation Accuracy: 80.00%

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
model.save("face_emotion_cnn_new.h5")
print("Model saved")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved

# %%
emotion_dict = {v:k for k,v in emotion_labels.items()}

face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)
ret, frame = cap.read()
cap.release()

if not ret:
    raise Exception("Camera capture failed")

gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

if len(faces) == 0:
    print("No face detected")
else:
    x,y,w,h = faces[0]
    face = gray[y:y+h, x:x+w]
    face = cv2.resize(face, (48,48))
    face = face / 255.0
    face = face.reshape(1,48,48,1)

    pred = model.predict(face)
    emotion_index = np.argmax(pred)
    confidence = pred[0][emotion_index] * 100

    print("Emotion:", emotion_dict[emotion_index])
    print(f"Confidence: {confidence:.2f}%")
# Out:
# No face detected

# %%
model.save("face_emotion_cnn_new.h5")
print("Model saved")
